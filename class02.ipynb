# %% [markdown]
# Assignment 1 Conditional Statements

# %% [markdown]
# question (1)

# %%
salary = float(input("700000: "))
service = int(input("10: "))

if service > 5:
    bonus = salary * 0.05
    print("Your bonus amount is:", bonus)

else:
    print("No bonus because service is 5 years or less")
# Out:
# Your bonus amount is: 35000.0

# %% [markdown]
# question (2)

# %%
age = int(input("18: "))

if age > 17:
    print("You are eligible for voting")

else:
    print("You are not eligible for voting")
# Out:
# You are eligible for voting

# %% [markdown]
# question (3)

# %%
number = int(input("10: "))

if number % 2 == 0:
    print("The number is Even")

else:
    print("The number is Odd")
# Out:
# The number is Even

# %% [markdown]
# question (4)

# %%
number = int(input("12: "))

if number % 7 == 0:
    print("The number is divisible by 7")

else:
    print("The number is not divisible by 7")
# Out:
# The number is not divisible by 7

# %% [markdown]
# question (5)

# %%
number = int(input("5: "))

if number % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# question (6)

# %%
length = int(input(6))
breadth = int(input(7))

if length == breadth:
    print("It is a Square")
else:
    print("It is a Rectangle")
# Out:
# It is a Rectangle

# %% [markdown]
# question (7)

# %%
num1 = int(input(2000))
num2 = int(input(1750))

if num1 > num2:
    print(num1)
else:
    print(num2)
# Out:
# 2000

# %% [markdown]
# question (8)

# %%
marks = int(input(75))

if marks < 25:
    print("F")
elif marks < 45:
    print("E")
elif marks < 50:
    print("D")
elif marks < 60:
    print("C")
elif marks < 80:
    print("B")
else:
    print("A")
# Out:
# B

# %% [markdown]
# question (9)

# %%
age = int(input("40"))
gender = input("Male")
marital_status = input("no")

if gender == "F":
    print("Urban areas only")

elif gender == "M":
    if age >= 20 and age <= 40:
        print("Anywhere")
    elif age > 40 and age <= 60:
        print("Urban areas only")
    else:
        print("ERROR")

else:
    print("ERROR")
# Out:
# ERROR
